# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.tail(3)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8520           NCJ29        10.60          Low Fat         0.035186
# 8521           FDN46         7.21          Regular         0.145221
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'Item_Outlet_Sales']

# %%
df["Item_Identifier"]
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
df["Item_Weight"]
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
df["Item_Outlet_Sales"]
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df["Outlet_Size"]
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3          NaN
# 4         High
#          ...
# 8518      High
# 8519       NaN
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %%
df["Item_Type"]
# Out:
# 0                       Dairy
# 1                 Soft Drinks
# 2                        Meat
# 3       Fruits and Vegetables
# 4                   Household
#                 ...
# 8518              Snack Foods
# 8519             Baking Goods
# 8520       Health and Hygiene
# 8521              Snack Foods
# 8522              Soft Drinks
# Name: Item_Type, Length: 8523, dtype: object

# %%
type(df["Item_Type"])
# Out:
# pandas.core.series.Series

# %%
list(df["Item_Type"])
# Out:
# ['Dairy',
#  'Soft Drinks',
#  'Meat',
#  'Fruits and Vegetables',
#  'Household',
#  'Baking Goods',
#  'Snack Foods',
#  'Snack Foods',
#  'Frozen Foods',
#  'Frozen Foods',
#  'Fruits and Vegetables',
#  'Dairy',
#  'Fruits and Vegetables',
#  'Snack Foods',
#  'Fruits and Vegetables',
#  'Breakfast',
#  'Health and Hygiene',
#  'Breakfast',
#  'Hard Drinks',
#  'Dairy',
#  'Snack Foods',
#  'Baking Goods',
#  'Household',
#  'Baking Goods',
#  'Frozen Foods',
#  'Household',
#  'Snack Foods',
#  'Hard Drinks',
#  'Dairy',
#  'Canned',
#  'Dairy',
#  'Health and Hygiene',
#  'Snack Foods',
#  'Breads',
#  'Soft Drinks',
#  'Health and Hygiene',
#  'Fruits and Vegetables',
#  'Soft Drinks',
#  'Snack Foods',
#  'Snack Foods',
#  'Dairy',
#  'Meat',
#  'Snack Foods',
#  'Canned',
#  'Canned',
#  'Dairy',
#  'Health and Hygiene',
#  'Canned',
#  'Baking Goods',
#  'Dairy',
#  'Health and Hygiene',
#  'Frozen Foods',
#  'Canned',
#  'Fruits and Vegetables',
#  'Household',
# ...

# %%
df[["Item_Type"]]
# Out:
#                   Item_Type
# 0                     Dairy
# 1               Soft Drinks
# 2                      Meat
# 3     Fruits and Vegetables
# 4                 Household
# ...                     ...
# 8518            Snack Foods
# 8519           Baking Goods
# 8520     Health and Hygiene
# 8521            Snack Foods
# 8522            Soft Drinks
#
# [8523 rows x 1 columns]

# %%
type(df[["Item_Type"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Item_Type', 'Item_MRP']]
# Out:
#                   Item_Type  Item_MRP
# 0                     Dairy  249.8092
# 1               Soft Drinks   48.2692
# 2                      Meat  141.6180
# 3     Fruits and Vegetables  182.0950
# 4                 Household   53.8614
# ...                     ...       ...
# 8518            Snack Foods  214.5218
# 8519           Baking Goods  108.1570
# 8520     Health and Hygiene   85.1224
# 8521            Snack Foods  103.1332
# 8522            Soft Drinks   75.4670
#
# [8523 rows x 2 columns]

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df[["Item_Identifier", "Item_Weight", "Item_Fat_Content"]]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content
# 0              FDA15        9.300          Low Fat
# 1              DRC01        5.920          Regular
# 2              FDN15       17.500          Low Fat
# 3              FDX07       19.200          Regular
# 4              NCD19        8.930          Low Fat
# ...              ...          ...              ...
# 8518           FDF22        6.865          Low Fat
# 8519           FDS36        8.380          Regular
# 8520           NCJ29       10.600          Low Fat
# 8521           FDN46        7.210          Regular
# 8522           DRG01       14.800          Low Fat
#
# [8523 rows x 3 columns]

# %%
sky = pd.read_excel("CSEEEE.xlsx")

# %%
sky.head()
# Out:
#   GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem       Unnamed: 1 Unnamed: 2  \
# 0                                         NaN              NaN        NaN
# 1                                         NaN              NaN        NaN
# 2                                     SL. NO.  STUDENT'S NAME    ROLL NO.
# 3                                         NaN              NaN        NaN
# 4                                           1   PRAVEEN KUMAR    22-CS-28
#
#          Unnamed: 3                  Unnamed: 4 Unnamed: 5
# 0               NaN                         NaN        NaN
# 1               NaN                         NaN        NaN
# 2  REGISTRATION NO.  CLASS ATTENDED (OUT OF 12)       IN %
# 3               NaN                         NaN        NaN
# 4       22157133001                          10      83.33

# %%
sky.head(5)
# Out:
#   GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem       Unnamed: 1 Unnamed: 2  \
# 0                                         NaN              NaN        NaN
# 1                                         NaN              NaN        NaN
# 2                                     SL. NO.  STUDENT'S NAME    ROLL NO.
# 3                                         NaN              NaN        NaN
# 4                                           1   PRAVEEN KUMAR    22-CS-28
#
#          Unnamed: 3                  Unnamed: 4 Unnamed: 5
# 0               NaN                         NaN        NaN
# 1               NaN                         NaN        NaN
# 2  REGISTRATION NO.  CLASS ATTENDED (OUT OF 12)       IN %
# 3               NaN                         NaN        NaN
# 4       22157133001                          10      83.33

# %%
sky.head(13)
# Out:
#    GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem         Unnamed: 1 Unnamed: 2  \
# 0                                          NaN                NaN        NaN
# 1                                          NaN                NaN        NaN
# 2                                      SL. NO.    STUDENT'S NAME    ROLL NO.
# 3                                          NaN                NaN        NaN
# 4                                            1     PRAVEEN KUMAR    22-CS-28
# 5                                            2  SATYARTHI PRAKASH   22-CS-53
# 6                                            3          AKASH RAJ   22-CS-56
# 7                                            4        PREM KUMAR    22-CS-23
# 8                                            5        FALAK UZMA    22-CS-49
# 9                                            6         ADANAN ALI   22-CS-21
# 10                                           7   MD SAHID MALLICK   22-CS-02
# ...

# %%
sky.head(16)
# Out:
#    GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem                Unnamed: 1  \
# 0                                          NaN                       NaN
# 1                                          NaN                       NaN
# 2                                      SL. NO.           STUDENT'S NAME
# 3                                          NaN                       NaN
# 4                                            1            PRAVEEN KUMAR
# 5                                            2         SATYARTHI PRAKASH
# 6                                            3                 AKASH RAJ
# 7                                            4               PREM KUMAR
# 8                                            5               FALAK UZMA
# 9                                            6                ADANAN ALI
# 10                                           7          MD SAHID MALLICK
# 11                                           8                MD FARDIN
# ...

# %%
sky[["Unnamed: 1", "Unnamed: 2", "Unnamed: 3"]]
# Out:
#           Unnamed: 1     Unnamed: 2        Unnamed: 3
# 0                NaN            NaN               NaN
# 1                NaN            NaN               NaN
# 2    STUDENT'S NAME        ROLL NO.  REGISTRATION NO.
# 3                NaN            NaN               NaN
# 4     PRAVEEN KUMAR        22-CS-28       22157133001
# ..               ...            ...               ...
# 67  SUDHANSHU SEKHAR  LE-23-CSE-103               NaN
# 68         ANKIT RAJ  LE-23-CSE-104               NaN
# 69     ADARSH DIVYAM  LE-23-CSE-105               NaN
# 70     SWEETY KUMARI  LE-23-CSE-106               NaN
# 71       JIYA RANJAN  LE-23-CSE-107               NaN
#
# [72 rows x 3 columns]

# %%
sky.tail(20)
# Out:
#    GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem              Unnamed: 1  \
# 52                                          49             RAHUL KUMAR
# 53                                          50             ARYA SHREE
# 54                                          51  RAHUL RANJAN CHAUDUARY
# 55                                          52         SANJEEV RANJAN
# 56                                          53        PRAGYA SATYARTHY
# 57                                          54           SURYA KAUSIK
# 58                                          55           TASHU KUMARI
# 59                                          56        AMIT KUMAR YADAV
# 60                                          57              SWETA RANI
# 61                                          58               HANSH RAJ
# 62                                          59               AYUSH RAJ
# 63                                          60            DEVESH KUMAR
# ...

# %%
sky.head(20)
# Out:
#    GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem                Unnamed: 1  \
# 0                                          NaN                       NaN
# 1                                          NaN                       NaN
# 2                                      SL. NO.           STUDENT'S NAME
# 3                                          NaN                       NaN
# 4                                            1            PRAVEEN KUMAR
# 5                                            2         SATYARTHI PRAKASH
# 6                                            3                 AKASH RAJ
# 7                                            4               PREM KUMAR
# 8                                            5               FALAK UZMA
# 9                                            6                ADANAN ALI
# 10                                           7          MD SAHID MALLICK
# 11                                           8                MD FARDIN
# ...

# %%
sky.tail(40)
# Out:
#    GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem              Unnamed: 1  \
# 32                                          29            ASHISH KUMAR
# 33                                          30           ANKUSH KUMAR
# 34                                          31          NISHANT RANJAN
# 35                                          32          MUSKAN KUMARI
# 36                                          33      PRINCE KUMAR SINGH
# 37                                          34          ANIKESH KUMAR
# 38                                          35           PRAVIN KUMAR
# 39                                          36               VIVEK RAJ
# 40                                          37           SWEETY KUMARI
# 41                                          38          YASVANT KUMAR
# 42                                          39           SOURAV KUMAR
# 43                                          40              ANNU PRIYA
# ...

# %%
sky.head()
# Out:
#   GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem       Unnamed: 1 Unnamed: 2  \
# 0                                         NaN              NaN        NaN
# 1                                         NaN              NaN        NaN
# 2                                     SL. NO.  STUDENT'S NAME    ROLL NO.
# 3                                         NaN              NaN        NaN
# 4                                           1   PRAVEEN KUMAR    22-CS-28
#
#          Unnamed: 3                  Unnamed: 4 Unnamed: 5
# 0               NaN                         NaN        NaN
# 1               NaN                         NaN        NaN
# 2  REGISTRATION NO.  CLASS ATTENDED (OUT OF 12)       IN %
# 3               NaN                         NaN        NaN
# 4       22157133001                          10      83.33

# %%
sky[['Unnamed: 1', 'Unnamed: 2']]
# Out:
#           Unnamed: 1     Unnamed: 2
# 0                NaN            NaN
# 1                NaN            NaN
# 2    STUDENT'S NAME        ROLL NO.
# 3                NaN            NaN
# 4     PRAVEEN KUMAR        22-CS-28
# ..               ...            ...
# 67  SUDHANSHU SEKHAR  LE-23-CSE-103
# 68         ANKIT RAJ  LE-23-CSE-104
# 69     ADARSH DIVYAM  LE-23-CSE-105
# 70     SWEETY KUMARI  LE-23-CSE-106
# 71       JIYA RANJAN  LE-23-CSE-107
#
# [72 rows x 2 columns]

# %%
sky.columns
# Out:
# Index(['GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'],
#       dtype='object')

# %%
type(sky)
# Out:
# pandas.core.frame.DataFrame

# %%
sky['Unnamed: 1']
# Out:
# 0                  NaN
# 1                  NaN
# 2      STUDENT'S NAME
# 3                  NaN
# 4       PRAVEEN KUMAR
#             ...
# 67    SUDHANSHU SEKHAR
# 68           ANKIT RAJ
# 69       ADARSH DIVYAM
# 70       SWEETY KUMARI
# 71         JIYA RANJAN
# Name: Unnamed: 1, Length: 72, dtype: object

# %%
type(sky['Unnamed: 1'])
# Out:
# pandas.core.series.Series

# %%
sky[['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3']]
# Out:
#           Unnamed: 1     Unnamed: 2        Unnamed: 3
# 0                NaN            NaN               NaN
# 1                NaN            NaN               NaN
# 2    STUDENT'S NAME        ROLL NO.  REGISTRATION NO.
# 3                NaN            NaN               NaN
# 4     PRAVEEN KUMAR        22-CS-28       22157133001
# ..               ...            ...               ...
# 67  SUDHANSHU SEKHAR  LE-23-CSE-103               NaN
# 68         ANKIT RAJ  LE-23-CSE-104               NaN
# 69     ADARSH DIVYAM  LE-23-CSE-105               NaN
# 70     SWEETY KUMARI  LE-23-CSE-106               NaN
# 71       JIYA RANJAN  LE-23-CSE-107               NaN
#
# [72 rows x 3 columns]

# %%
sky.tail(10)
# Out:
#    GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem          Unnamed: 1  \
# 62                                          59           AYUSH RAJ
# 63                                          60        DEVESH KUMAR
# 64                                          61         VIVEK KUMAR
# 65                                          62  MANISH KANT BHARTI
# 66                                          63     PUSHPESH THAKUR
# 67                                          64    SUDHANSHU SEKHAR
# 68                                          65           ANKIT RAJ
# 69                                          66       ADARSH DIVYAM
# 70                                          67       SWEETY KUMARI
# 71                                          68         JIYA RANJAN
#
#        Unnamed: 2   Unnamed: 3 Unnamed: 4 Unnamed: 5
# 62       22-CS-51  22157133059          2      16.67
# 63       22-CS-50  22157133060          0       0.00
# 64       22-CS-16  22157133061          2      16.67
# ...

# %%
import lxml

# %%
import pandas as pd

# %%
sky = pd.read_excel("CSEEEE.xlsx")

# %%
sky.head()
# Out:
#   GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem       Unnamed: 1 Unnamed: 2  \
# 0                                         NaN              NaN        NaN
# 1                                         NaN              NaN        NaN
# 2                                     SL. NO.  STUDENT'S NAME    ROLL NO.
# 3                                         NaN              NaN        NaN
# 4                                           1   PRAVEEN KUMAR    22-CS-28
#
#          Unnamed: 3                  Unnamed: 4 Unnamed: 5
# 0               NaN                         NaN        NaN
# 1               NaN                         NaN        NaN
# 2  REGISTRATION NO.  CLASS ATTENDED (OUT OF 12)       IN %
# 3               NaN                         NaN        NaN
# 4       22157133001                          10      83.33

# %%
sky.head(10)
# Out:
#   GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem         Unnamed: 1 Unnamed: 2  \
# 0                                         NaN                NaN        NaN
# 1                                         NaN                NaN        NaN
# 2                                     SL. NO.    STUDENT'S NAME    ROLL NO.
# 3                                         NaN                NaN        NaN
# 4                                           1     PRAVEEN KUMAR    22-CS-28
# 5                                           2  SATYARTHI PRAKASH   22-CS-53
# 6                                           3          AKASH RAJ   22-CS-56
# 7                                           4        PREM KUMAR    22-CS-23
# 8                                           5        FALAK UZMA    22-CS-49
# 9                                           6         ADANAN ALI   22-CS-21
#
#          Unnamed: 3                  Unnamed: 4 Unnamed: 5
# 0               NaN                         NaN        NaN
# ...

# %%
sky.head(17)
# Out:
#    GEC JAMUI\nSESSION (2022-26) (CSE)\n3rd Sem                Unnamed: 1  \
# 0                                          NaN                       NaN
# 1                                          NaN                       NaN
# 2                                      SL. NO.           STUDENT'S NAME
# 3                                          NaN                       NaN
# 4                                            1            PRAVEEN KUMAR
# 5                                            2         SATYARTHI PRAKASH
# 6                                            3                 AKASH RAJ
# 7                                            4               PREM KUMAR
# 8                                            5               FALAK UZMA
# 9                                            6                ADANAN ALI
# 10                                           7          MD SAHID MALLICK
# 11                                           8                MD FARDIN
# ...
